# %%
# THD (Dynamic Linearity)
# 
# Tests:
# - Harmonic distortion
# - Nonlinear behavior under sine excitation
# - Frequency-domain distortion

# Measured by:
# - Full-scale sine input
# - FFT
# - Harmonic extraction
